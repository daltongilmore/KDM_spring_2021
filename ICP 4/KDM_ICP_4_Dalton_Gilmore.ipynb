# %% [markdown]
# # Setting up PySpark in Colab

# %% [markdown]
# Download Java

# %%
# !sudo apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 252 kB in 1s (215 kB/s)
# Reading package lists... Done

# %% [markdown]
# Install Apache Spark 3.0.1 with Hadoop 2.7

# %%
# !wget -q https://www-us.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz

# %%
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz

# %% [markdown]
# Install the findspark library - it will locate Spark on the system and import it as a regular library

# %%
# !pip install -q findspark

# %% [markdown]
# Set the environment path - this will enable us to run Pyspark in the Colab environment

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"

# %% [markdown]
# Import findspark and use the findspark.init() method

# %%
import findspark
findspark.init()

# %% [markdown]
# If you want to know the location where Spark is installed, use findspark.find()

# %%
findspark.find()
# Out:
# '/content/spark-3.0.1-bin-hadoop2.7'

# %% [markdown]
# Import SparkSession from pyspark.sql and create a SparkSession, which is the entry point to Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %% [markdown]
# Print the SparkSession variable.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://9668e6dacd84:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Load the dataset using the read.csv module

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)
df.printSchema()
# Out:
# root
#  |-- customerID: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- SeniorCitizen: integer (nullable = true)
#  |-- Partner: string (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- PhoneService: string (nullable = true)
#  |-- MultipleLines: string (nullable = true)
#  |-- InternetService: string (nullable = true)
#  |-- OnlineSecurity: string (nullable = true)
#  |-- OnlineBackup: string (nullable = true)
#  |-- DeviceProtection: string (nullable = true)
#  |-- TechSupport: string (nullable = true)
#  |-- StreamingTV: string (nullable = true)
#  |-- StreamingMovies: string (nullable = true)
#  |-- Contract: string (nullable = true)
#  |-- PaperlessBilling: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- MonthlyCharges: double (nullable = true)
#  |-- TotalCharges: string (nullable = true)
#  |-- Churn: string (nullable = true)

# %% [markdown]
# # Transformations

# %% [markdown]
# ## Conditional If Statement

# %% [markdown]
# Create a slice of data that elicits which rows involve a check as the payment method and which do not (1 = has check, 0 = does not have check)

# %%
from pyspark.sql import functions as F
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)
df = df.withColumn('has check',\
     F.when(\
     F.lower(\
     F.col('PaymentMethod')).contains('check'),\
     F.lit(1)).\
                    otherwise(F.lit(0)))
df.select('has check', 'PaymentMethod').show(50)
# Out:
# +---------+--------------------+
# |has check|       PaymentMethod|
# +---------+--------------------+
# |        1|    Electronic check|
# |        1|        Mailed check|
# |        1|        Mailed check|
# |        0|Bank transfer (au...|
# |        1|    Electronic check|
# |        1|    Electronic check|
# |        0|Credit card (auto...|
# |        1|        Mailed check|
# |        1|    Electronic check|
# |        0|Bank transfer (au...|
# |        1|        Mailed check|
# |        0|Credit card (auto...|
# |        0|Credit card (auto...|
# |        0|Bank transfer (au...|
# |        1|    Electronic check|
# |        0|Credit card (auto...|
# |        1|        Mailed check|
# |        0|Bank transfer (au...|
# |        0|Credit card (auto...|
# |        1|    Electronic check|
# |        1|    Electronic check|
# |        0|Bank transfer (au...|
# |        1|        Mailed check|
# |        0|Credit card (auto...|
# |        0|Credit card (auto...|
# |        0|Bank transfer (au...|
# |        1|    Electronic check|
# |        1|    Electronic check|
# |        0|Credit card (auto...|
# |        1|        Mailed check|
# |        0|Credit card (auto...|
# |        0|Credit card (auto...|
# |        1|        Mailed check|
# |        0|Bank transfer (au...|
# |        0|Bank transfer (au...|
# |        0|Bank transfer (au...|
# |        1|    Electronic check|
# |        0|Credit card (auto...|
# |        1|    Electronic check|
# |        0|Bank transfer (au...|
# |        1|        Mailed check|
# |        0|Credit card (auto...|
# |        1|        Mailed check|
# |        0|Credit card (auto...|
# |        1|    Electronic check|
# |        1|    Electronic check|
# |        1|        Mailed check|
# |        1|    Electronic check|
# |        0|Credit card (auto...|
# |        0|Credit card (auto...|
# +---------+--------------------+
# only showing top 50 rows

# %% [markdown]
# ## Sorting

# %% [markdown]
# Sort the data based on the MonthlyCharges column, followed by the TotalCharges column

# %%
from pyspark.sql import functions as F
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)
df.sort(F.col("MonthlyCharges"), F.col("TotalCharges")).show(50, truncate=False)
# Out:
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+-------------------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|MultipleLines|InternetService|OnlineSecurity     |OnlineBackup       |DeviceProtection   |TechSupport        |StreamingTV        |StreamingMovies    |Contract      |PaperlessBilling|PaymentMethod            |MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+-------------------------+--------------+------------+-----+
# |6823-SIDFQ|Male  |0            |No     |No        |28    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Credit card (automatic)  |18.25         |534.7       |No   |
# |9764-REAFF|Female|0            |Yes    |No        |59    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Bank transfer (automatic)|18.4          |1057.85     |No   |
# |0827-ITJPH|Male  |0            |No     |No        |36    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |Yes             |Credit card (automatic)  |18.55         |689         |No   |
# |0621-CXBKL|Female|0            |No     |No        |53    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Mailed check             |18.7          |1005.7      |No   |
# |9945-PSVIP|Female|0            |Yes    |Yes       |25    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |Yes             |Mailed check             |18.7          |383.65      |No   |
# |9426-SXNHE|Female|0            |No     |No        |2     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Bank transfer (automatic)|18.75         |53.15       |No   |
# |8464-EETCQ|Male  |0            |No     |No        |57    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Credit card (automatic)  |18.8          |1094.35     |No   |
# |2967-MXRAV|Male  |0            |Yes    |Yes       |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Mailed check             |18.8          |18.8        |No   |
# |3387-PLKUI|Female|0            |Yes    |Yes       |13    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.8          |251.25      |No   |
# |7473-ZBDSN|Female|0            |Yes    |Yes       |14    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Mailed check             |18.8          |255.55      |No   |
# |7369-TRPFD|Male  |0            |No     |No        |19    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Mailed check             |18.8          |279.2       |No   |
# |6508-NJYRO|Male  |0            |Yes    |No        |15    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Mailed check             |18.8          |294.95      |No   |
# |3806-YAZOV|Female|0            |No     |No        |3     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.8          |56          |No   |
# |5863-OOKCL|Female|0            |No     |No        |10    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.85         |163.2       |No   |
# |8992-CEUEN|Female|0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Electronic check         |18.85         |18.85       |No   |
# |9318-NKNFC|Male  |0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Mailed check             |18.85         |18.85       |Yes  |
# |0620-XEFWH|Male  |0            |Yes    |Yes       |4     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.85         |84.2        |No   |
# |3572-UUHRS|Male  |0            |No     |No        |45    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Bank transfer (automatic)|18.85         |867.3       |No   |
# |9975-SKRNR|Male  |0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.9          |18.9        |No   |
# |5025-GOOKI|Female|0            |No     |No        |20    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Credit card (automatic)  |18.9          |347.65      |No   |
# |3719-TDVQB|Female|1            |Yes    |No        |54    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |Yes             |Mailed check             |18.95         |1031.1      |No   |
# |7968-QUXNS|Male  |0            |No     |No        |6     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |18.95         |110.15      |No   |
# |1386-ZIKUV|Male  |0            |No     |No        |7     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Mailed check             |18.95         |130.55      |No   |
# |9025-ZRPVR|Male  |0            |No     |No        |9     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Mailed check             |18.95         |185.6       |Yes  |
# |7469-LKBCI|Male  |0            |No     |No        |16    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Credit card (automatic)  |18.95         |326.8       |No   |
# |4635-EJYPD|Male  |0            |Yes    |Yes       |32    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Mailed check             |18.95         |613.95      |No   |
# |0661-KQHNK|Female|0            |Yes    |Yes       |6     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Credit card (automatic)  |19.0          |105.5       |No   |
# |1423-BMPBQ|Female|0            |Yes    |Yes       |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Mailed check             |19.0          |19          |No   |
# |1218-VKFPE|Female|0            |Yes    |Yes       |12    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.0          |233.55      |Yes  |
# |2023-VQFDL|Male  |0            |No     |No        |18    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Electronic check         |19.0          |348.8       |No   |
# |7234-KMNRQ|Male  |0            |No     |No        |4     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.0          |73.45       |No   |
# |5222-JCXZT|Male  |0            |No     |No        |4     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.0          |78.9        |No   |
# |9732-OUYRN|Female|0            |Yes    |No        |49    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Credit card (automatic)  |19.0          |918.7       |No   |
# |1991-VOPLL|Female|0            |No     |No        |9     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.05         |157.65      |No   |
# |1015-OWJKI|Male  |0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.05         |19.05       |No   |
# |2005-DWQZJ|Female|0            |Yes    |Yes       |8     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Mailed check             |19.05         |201.7       |No   |
# |0307-BCOPK|Female|0            |No     |No        |16    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Mailed check             |19.05         |326.65      |No   |
# |1431-CYWMH|Female|0            |Yes    |Yes       |22    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Bank transfer (automatic)|19.05         |454.05      |No   |
# |9467-ROOLM|Female|0            |No     |No        |25    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.05         |461.3       |No   |
# |4774-HHGGS|Male  |0            |Yes    |No        |30    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Mailed check             |19.05         |637.55      |No   |
# |4530-NDRKU|Female|0            |Yes    |Yes       |42    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |Yes             |Electronic check         |19.05         |761.85      |No   |
# |9451-WLYRI|Female|0            |Yes    |No        |53    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Credit card (automatic)  |19.05         |990.45      |No   |
# |7009-PCARS|Male  |0            |No     |Yes       |55    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Bank transfer (automatic)|19.1          |1001.5      |No   |
# |4163-HFTUK|Male  |0            |No     |No        |51    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Electronic check         |19.1          |1007.8      |No   |
# |1697-LYYYX|Female|0            |Yes    |Yes       |61    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|One year      |No              |Credit card (automatic)  |19.1          |1143.8      |No   |
# |9500-WBGRP|Male  |0            |No     |No        |69    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |Yes             |Mailed check             |19.1          |1268.85     |No   |
# |0825-CPPQH|Female|0            |Yes    |No        |71    |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Two year      |No              |Credit card (automatic)  |19.1          |1372.45     |No   |
# |6569-KTMDU|Female|0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.1          |19.1        |No   |
# |6121-VZNQB|Female|0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|Yes             |Mailed check             |19.1          |19.1        |Yes  |
# |9441-QHEVC|Male  |0            |No     |No        |1     |Yes         |No           |No             |No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|Month-to-month|No              |Mailed check             |19.1          |19.1        |No   |
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+-------------------------+--------------+------------+-----+
# only showing top 50 rows

# %% [markdown]
# ## Filtering

# %% [markdown]
# Filter the data by removing rows without phone service or internet service

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

df = df.sort(F.col("MonthlyCharges"))
df = df.filter(df.PhoneService != 'No')
df = df.filter(df.InternetService != 'No')

df.show(40, truncate=False)
# Out:
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|MultipleLines|InternetService|OnlineSecurity|OnlineBackup|DeviceProtection|TechSupport|StreamingTV|StreamingMovies|Contract      |PaperlessBilling|PaymentMethod            |MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+
# |6959-UWKHF|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |42.9          |42.9        |Yes  |
# |7587-RZNME|Male  |0            |No     |No        |3     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |43.3          |123.65      |Yes  |
# |4544-RXFMG|Male  |0            |Yes    |Yes       |8     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |One year      |Yes             |Mailed check             |43.45         |345.5       |No   |
# |9327-QSDED|Male  |0            |No     |No        |8     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |43.55         |335.4       |No   |
# |4570-QHXHL|Female|0            |No     |No        |9     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |43.75         |405.7       |No   |
# |2604-XVDAM|Female|0            |No     |No        |12    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Bank transfer (automatic)|43.8          |540.95      |No   |
# |3638-DIMPH|Female|0            |Yes    |No        |13    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |One year      |No              |Electronic check         |43.8          |592.65      |No   |
# |1478-VPOAD|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |43.8          |43.8        |No   |
# |1125-SNVCK|Female|1            |No     |No        |49    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |43.8          |2106.05     |No   |
# |6650-VJONK|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Bank transfer (automatic)|43.85         |43.85       |No   |
# |4452-QIIEB|Male  |0            |No     |No        |7     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |43.9          |278.4       |No   |
# |1895-QTKDO|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Credit card (automatic)  |43.95         |43.95       |No   |
# |3798-EPWRR|Female|1            |No     |No        |2     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |43.95         |85.1        |No   |
# |3085-QUOZK|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |43.95         |43.95       |Yes  |
# |1942-OQFRW|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |44.0          |44          |No   |
# |5522-JBWMO|Male  |0            |No     |Yes       |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |44.0          |44          |No   |
# |8082-GHXOP|Male  |0            |No     |Yes       |13    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |44.0          |659.35      |No   |
# |9214-EKVXR|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Mailed check             |44.0          |44          |No   |
# |8720-RQSBJ|Male  |1            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |44.0          |44          |No   |
# |3961-SXAXY|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Bank transfer (automatic)|44.05         |44.05       |No   |
# |4566-QVRRW|Female|0            |Yes    |No        |11    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.05         |483.7       |Yes  |
# |1635-FJFCC|Female|0            |No     |No        |5     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Credit card (automatic)  |44.05         |202.15      |No   |
# |7636-PEPNS|Female|0            |Yes    |Yes       |58    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |One year      |Yes             |Mailed check             |44.1          |2413.05     |No   |
# |4855-SNKMY|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.1          |44.1        |Yes  |
# |6145-NNPNO|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Bank transfer (automatic)|44.15         |44.15       |No   |
# |3754-DXMRT|Male  |1            |No     |No        |2     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.15         |92.65       |Yes  |
# |7663-RGWBC|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Mailed check             |44.15         |44.15       |Yes  |
# |8775-CEBBJ|Female|0            |No     |No        |9     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Bank transfer (automatic)|44.2          |403.35      |Yes  |
# |8887-IPQNC|Female|0            |Yes    |No        |7     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Mailed check             |44.25         |313.45      |No   |
# |7963-GQRMY|Female|0            |Yes    |Yes       |3     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |44.3          |134.5       |Yes  |
# |0224-RLWWD|Female|1            |No     |No        |2     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.3          |89.3        |No   |
# |0082-LDZUE|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Mailed check             |44.3          |44.3        |No   |
# |3808-HFKDE|Female|0            |No     |No        |20    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.35         |927.15      |No   |
# |6142-VSJQO|Female|0            |Yes    |Yes       |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Bank transfer (automatic)|44.35         |44.35       |Yes  |
# |2372-HWUHI|Male  |0            |No     |No        |2     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Electronic check         |44.35         |81.25       |Yes  |
# |6954-OOYZZ|Male  |0            |Yes    |No        |18    |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Bank transfer (automatic)|44.35         |768.05      |No   |
# |6982-SSHFK|Male  |0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |44.4          |44.4        |Yes  |
# |3589-PPVKW|Male  |0            |No     |No        |9     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Mailed check             |44.4          |348.15      |No   |
# |0415-MOSGF|Female|0            |No     |No        |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|No              |Mailed check             |44.4          |44.4        |Yes  |
# |4361-JEIVL|Male  |0            |No     |Yes       |1     |Yes         |No           |DSL            |No            |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |44.4          |44.4        |Yes  |
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+
# only showing top 40 rows

# %% [markdown]
# # Actions

# %% [markdown]
# ## Collect

# %% [markdown]
# Collect the data in the customerID row by returning its elements as an array

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

df.select('customerID').collect()
# Out:
# [Row(customerID='7590-VHVEG'),
#  Row(customerID='5575-GNVDE'),
#  Row(customerID='3668-QPYBK'),
#  Row(customerID='7795-CFOCW'),
#  Row(customerID='9237-HQITU'),
#  Row(customerID='9305-CDSKC'),
#  Row(customerID='1452-KIOVK'),
#  Row(customerID='6713-OKOMC'),
#  Row(customerID='7892-POOKP'),
#  Row(customerID='6388-TABGU'),
#  Row(customerID='9763-GRSKD'),
#  Row(customerID='7469-LKBCI'),
#  Row(customerID='8091-TTVAX'),
#  Row(customerID='0280-XJGEX'),
#  Row(customerID='5129-JLPIS'),
#  Row(customerID='3655-SNQYZ'),
#  Row(customerID='8191-XWSZG'),
#  Row(customerID='9959-WOFKT'),
#  Row(customerID='4190-MFLUW'),
#  Row(customerID='4183-MYFRB'),
#  Row(customerID='8779-QRDMV'),
#  Row(customerID='1680-VDCWW'),
#  Row(customerID='1066-JKSGK'),
#  Row(customerID='3638-WEABW'),
#  Row(customerID='6322-HRPFA'),
#  Row(customerID='6865-JZNKO'),
#  Row(customerID='6467-CHFZW'),
#  Row(customerID='8665-UTDHZ'),
#  Row(customerID='5248-YGIJN'),
#  Row(customerID='8773-HHUOZ'),
#  Row(customerID='3841-NFECX'),
#  Row(customerID='4929-XIHVW'),
#  Row(customerID='6827-IEAUQ'),
#  Row(customerID='7310-EGVHZ'),
#  Row(customerID='3413-BMNZE'),
#  Row(customerID='6234-RAAPL'),
#  Row(customerID='6047-YHPVI'),
#  Row(customerID='6572-ADKRS'),
#  Row(customerID='5380-WJKOV'),
#  Row(customerID='8168-UQWWF'),
#  Row(customerID='8865-TNMNX'),
#  Row(customerID='9489-DEDVP'),
#  Row(customerID='9867-JCZSP'),
#  Row(customerID='4671-VJLCL'),
#  Row(customerID='4080-IIARD'),
#  Row(customerID='3714-NTNFO'),
#  Row(customerID='5948-UJZLF'),
#  Row(customerID='7760-OYPDY'),
#  Row(customerID='7639-LIAYI'),
#  Row(customerID='2954-PIBKO'),
#  Row(customerID='8012-SOUDQ'),
#  Row(customerID='9420-LOJKX'),
#  Row(customerID='6575-SUVOI'),
#  Row(customerID='7495-OOKFY'),
#  Row(customerID='4667-QONEA'),
#  Row(customerID='1658-BYGOY'),
#  Row(customerID='8769-KKTPH'),
#  Row(customerID='5067-XJQFU'),
#  Row(customerID='3957-SQXML'),
#  Row(customerID='5954-BDFSG'),
#  Row(customerID='0434-CSFON'),
#  Row(customerID='1215-FIGMP'),
#  Row(customerID='0526-SXDJP'),
#  Row(customerID='0557-ASKVU'),
#  Row(customerID='5698-BQJOH'),
#  Row(customerID='5122-CYFXA'),
#  Row(customerID='8627-ZYGSZ'),
#  Row(customerID='3410-YOQBQ'),
#  Row(customerID='3170-NMYVV'),
#  Row(customerID='7410-OIEDU'),
#  Row(customerID='2273-QCKXA'),
#  Row(customerID='0731-EBJQB'),
#  Row(customerID='1891-QRQSA'),
#  Row(customerID='8028-PNXHQ'),
#  Row(customerID='5630-AHZIL'),
#  Row(customerID='2673-CXQEU'),
#  Row(customerID='6416-JNVRK'),
#  Row(customerID='5590-ZSKRV'),
#  Row(customerID='0191-ZHSKZ'),
#  Row(customerID='3887-PBQAO'),
#  Row(customerID='5919-TMRGD'),
#  Row(customerID='8108-UXRQN'),
#  Row(customerID='9191-MYQKX'),
#  Row(customerID='9919-YLNNG'),
#  Row(customerID='0318-ZOPWS'),
#  Row(customerID='4445-ZJNMU'),
#  Row(customerID='4808-YNLEU'),
#  Row(customerID='1862-QRWPE'),
#  Row(customerID='2796-NNUFI'),
#  Row(customerID='3016-KSVCP'),
#  Row(customerID='4767-HZZHQ'),
#  Row(customerID='2424-WVHPL'),
#  Row(customerID='7233-PAHHL'),
#  Row(customerID='6067-NGCEU'),
#  Row(customerID='9848-JQJTX'),
#  Row(customerID='8637-XJIVR'),
#  Row(customerID='9803-FTJCG'),
#  Row(customerID='0278-YXOOG'),
#  Row(customerID='3212-KXOCR'),
#  Row(customerID='4598-XLKNJ'),
#  Row(customerID='6380-ARCEH'),
#  Row(customerID='3679-XASPY'),
#  Row(customerID='7123-WQUHX'),
#  Row(customerID='5386-THSLQ'),
#  Row(customerID='3192-NQECA'),
#  Row(customerID='6180-YBIQI'),
#  Row(customerID='6728-DKUCO'),
#  Row(customerID='9750-BOOHV'),
#  Row(customerID='8597-CWYHH'),
#  Row(customerID='2848-YXSMW'),
#  Row(customerID='0486-HECZI'),
#  Row(customerID='4549-ZDQYY'),
#  Row(customerID='5712-AHQNN'),
#  Row(customerID='4846-WHAFZ'),
#  Row(customerID='5256-SKJGO'),
#  Row(customerID='3071-VBYPO'),
#  Row(customerID='9560-BBZXK'),
#  Row(customerID='5299-RULOA'),
#  Row(customerID='8402-OOOHJ'),
#  Row(customerID='9445-ZUEQE'),
#  Row(customerID='1091-SOZGA'),
#  Row(customerID='2928-HLDBA'),
#  Row(customerID='0404-SWRVG'),
#  Row(customerID='6497-TILVL'),
#  Row(customerID='7219-TLZHO'),
#  Row(customerID='4622-YNKIJ'),
#  Row(customerID='4412-YLTKF'),
#  Row(customerID='6734-PSBAW'),
#  Row(customerID='3930-ZGWVE'),
#  Row(customerID='2639-UGMAZ'),
#  Row(customerID='2876-GZYZC'),
#  Row(customerID='6207-WIOLX'),
#  Row(customerID='8587-XYZSF'),
#  Row(customerID='3091-FYHKI'),
#  Row(customerID='2372-HWUHI'),
#  Row(customerID='7799-LGRDP'),
#  Row(customerID='7850-VWJUU'),
#  Row(customerID='3774-VBNXY'),
#  Row(customerID='6217-KDYWC'),
#  Row(customerID='0390-DCFDQ'),
#  Row(customerID='3146-MSEGF'),
#  Row(customerID='4080-OGPJL'),
#  Row(customerID='1095-WGNGG'),
#  Row(customerID='2636-SJDOU'),
#  Row(customerID='1131-QQZEB'),
#  Row(customerID='5716-EZXZN'),
#  Row(customerID='6837-BJYDQ'),
#  Row(customerID='2135-RXIHG'),
#  Row(customerID='6440-DKQGE'),
#  Row(customerID='3466-BYAVD'),
#  Row(customerID='3780-YVMFA'),
#  Row(customerID='3874-EQOEP'),
#  Row(customerID='1679-JRFBR'),
#  Row(customerID='9073-ZZIAY'),
#  Row(customerID='3077-RSNTJ'),
#  Row(customerID='6551-GNYDG'),
#  Row(customerID='9167-APMXZ'),
#  Row(customerID='2749-CTKAJ'),
#  Row(customerID='6371-NZYEG'),
#  Row(customerID='7554-NEWDD'),
#  Row(customerID='8992-VONJD'),
#  Row(customerID='0867-MKZVY'),
#  Row(customerID='4482-EWFMI'),
#  Row(customerID='4648-YPBTM'),
#  Row(customerID='2907-ILJBN'),
#  Row(customerID='6345-FZOQH'),
#  Row(customerID='3376-BMGFE'),
#  Row(customerID='5997-OPVFA'),
#  Row(customerID='3445-HXXGF'),
#  Row(customerID='1159-WFSGR'),
#  Row(customerID='7654-YWJUF'),
#  Row(customerID='1875-QIVME'),
#  Row(customerID='6727-IOTLZ'),
#  Row(customerID='0691-JVSYA'),
#  Row(customerID='5918-VUKWP'),
#  Row(customerID='1744-JHKYS'),
#  Row(customerID='2656-FMOKZ'),
#  Row(customerID='2070-FNEXE'),
#  Row(customerID='5947-SGKCL'),
#  Row(customerID='3712-PKXZA'),
#  Row(customerID='6317-YPKDH'),
#  Row(customerID='6582-OIVSP'),
#  Row(customerID='9367-WXLCH'),
#  Row(customerID='5524-KHNJP'),
#  Row(customerID='1918-ZBFQJ'),
#  Row(customerID='1024-GUALD'),
#  Row(customerID='4827-USJHP'),
#  Row(customerID='8167-GJLRN'),
#  Row(customerID='0956-SYCWG'),
#  Row(customerID='8017-UVSZU'),
#  Row(customerID='7100-FQPRV'),
#  Row(customerID='2472-OVKUP'),
#  Row(customerID='2984-RGEYA'),
#  Row(customerID='9680-NIAUV'),
#  Row(customerID='2146-EGVDT'),
#  Row(customerID='2604-IJPDU'),
#  Row(customerID='9178-JHUVJ'),
#  Row(customerID='6168-YBYNP'),
#  Row(customerID='7255-SSFBC'),
#  Row(customerID='3645-DEYGF'),
#  Row(customerID='9323-HGFWY'),
#  Row(customerID='8544-GOQSH'),
#  Row(customerID='3363-DTIVD'),
#  Row(customerID='7018-WBJNK'),
#  Row(customerID='9142-KZXOP'),
#  Row(customerID='7674-YTAFD'),
#  Row(customerID='6348-SNFUS'),
#  Row(customerID='1285-OKIPP'),
#  Row(customerID='7825-ECJRF'),
#  Row(customerID='1347-KTTTA'),
#  Row(customerID='7841-TZDMQ'),
#  Row(customerID='4195-NZGTA'),
#  Row(customerID='7157-SMCFK'),
#  Row(customerID='4709-LKHYG'),
#  Row(customerID='2504-DSHIH'),
#  Row(customerID='0699-NDKJM'),
#  Row(customerID='9286-BHDQG'),
#  Row(customerID='0230-WEQUW'),
#  Row(customerID='2040-LDIWQ'),
#  Row(customerID='6496-JDSSB'),
#  Row(customerID='9408-SSNVZ'),
#  Row(customerID='4443-EMBNA'),
#  Row(customerID='6469-MRVET'),
#  Row(customerID='0742-MOABM'),
#  Row(customerID='5961-VUSRV'),
#  Row(customerID='6778-JFCMK'),
#  Row(customerID='6341-JVQGF'),
#  Row(customerID='2232-DMLXU'),
#  Row(customerID='4811-JBUVU'),
#  Row(customerID='0945-TSONX'),
#  Row(customerID='2651-ZCBXV'),
#  Row(customerID='3316-UWXUY'),
#  Row(customerID='8937-RDTHP'),
#  Row(customerID='7083-MIOPC'),
#  Row(customerID='1984-GPTEH'),
#  Row(customerID='1251-KRREG'),
#  Row(customerID='0621-JFHOL'),
#  Row(customerID='9903-LYSAB'),
#  Row(customerID='0094-OIFMO'),
#  Row(customerID='9227-UAQFT'),
#  Row(customerID='7301-ABVAD'),
#  Row(customerID='6614-FHDBO'),
#  Row(customerID='7576-ASEJU'),
#  Row(customerID='9058-HRZSV'),
#  Row(customerID='4522-AKYLR'),
#  Row(customerID='0221-WMXNQ'),
#  Row(customerID='0303-UNCIP'),
#  Row(customerID='9947-OTFQU'),
#  Row(customerID='0322-YINQP'),
#  Row(customerID='0959-WHOKV'),
#  Row(customerID='4075-JFPGR'),
#  Row(customerID='4629-NRXKX'),
#  Row(customerID='9514-JDSKI'),
#  Row(customerID='3282-ZISZV'),
#  Row(customerID='3675-YDUPJ'),
#  Row(customerID='4111-BNXIF'),
#  Row(customerID='7017-VFHAY'),
#  Row(customerID='6655-LHBYW'),
#  Row(customerID='4959-JOSRX'),
#  Row(customerID='5046-NUHWD'),
#  Row(customerID='7273-TEFQD'),
#  Row(customerID='3606-TWKGI'),
#  Row(customerID='7529-ZDFXI'),
#  Row(customerID='7605-BDWDC'),
#  Row(customerID='1950-KSVVJ'),
#  Row(customerID='0123-CRBRT'),
#  Row(customerID='6292-TOSSS'),
#  Row(customerID='3197-ARFOY'),
#  Row(customerID='6323-AYBRX'),
#  Row(customerID='7014-ZZXAW'),
#  Row(customerID='4385-GZQXV'),
#  Row(customerID='7633-MVPUY'),
#  Row(customerID='6366-ZGQGL'),
#  Row(customerID='4716-HHKQH'),
#  Row(customerID='5940-AHUHD'),
#  Row(customerID='6432-TWQLB'),
#  Row(customerID='4484-GLZOU'),
#  Row(customerID='3179-GBRWV'),
#  Row(customerID='8645-KWHJO'),
#  Row(customerID='4130-MZLCC'),
#  Row(customerID='0314-TKOSI'),
#  Row(customerID='8229-MYEJZ'),
#  Row(customerID='2080-SRCDE'),
#  Row(customerID='9577-WJVCQ'),
#  Row(customerID='9512-UIBFX'),
#  Row(customerID='6202-DYYFX'),
#  Row(customerID='3808-HFKDE'),
#  Row(customerID='5583-SXDAG'),
#  Row(customerID='3488-PGMQJ'),
#  Row(customerID='3580-REOAC'),
#  Row(customerID='7534-BFESC'),
#  Row(customerID='3727-OWVYD'),
#  Row(customerID='2294-SALNE'),
#  Row(customerID='4847-TAJYI'),
#  Row(customerID='1563-IWQEX'),
#  Row(customerID='8203-XJZRC'),
#  Row(customerID='6556-DBKZF'),
#  Row(customerID='6851-WEFYX'),
#  Row(customerID='2985-JUUBZ'),
#  Row(customerID='6390-DSAZX'),
#  Row(customerID='0895-LMRSF'),
#  Row(customerID='8098-LLAZX'),
#  Row(customerID='8266-VBFQL'),
#  Row(customerID='8181-YHCMF'),
#  Row(customerID='2240-HSJQD'),
#  Row(customerID='1248-DYXUB'),
#  Row(customerID='0265-EDXBD'),
#  Row(customerID='4115-BNPJY'),
#  Row(customerID='3167-SNQPL'),
#  Row(customerID='4091-TVOCN'),
#  Row(customerID='1098-TDVUQ'),
#  Row(customerID='7277-OZCGZ'),
#  Row(customerID='1557-EMYVT'),
#  Row(customerID='2799-ARNLO'),
#  Row(customerID='7563-BIUPC'),
#  Row(customerID='5027-YOCXN'),
#  Row(customerID='3973-SKMLN'),
#  Row(customerID='2321-OMBXY'),
#  Row(customerID='2840-XANRC'),
#  Row(customerID='6745-JEFZB'),
#  Row(customerID='5020-ZSTTY'),
#  Row(customerID='9880-TDQAC'),
#  Row(customerID='8705-WZCYL'),
#  Row(customerID='7102-JJVTX'),
#  Row(customerID='8626-PTQGE'),
#  Row(customerID='4983-CLMLV'),
#  Row(customerID='5701-YVSVF'),
#  Row(customerID='5804-LEPIM'),
#  Row(customerID='5697-GOMBF'),
#  Row(customerID='2739-CACDQ'),
#  Row(customerID='9385-EHGDO'),
#  Row(customerID='9498-FIMXL'),
#  Row(customerID='2379-GYFLQ'),
#  Row(customerID='0122-OAHPZ'),
#  Row(customerID='2868-SNELZ'),
#  Row(customerID='4322-RCYMT'),
#  Row(customerID='6680-NENYN'),
#  Row(customerID='2088-IEBAU'),
#  Row(customerID='7982-VCELR'),
#  Row(customerID='1343-EHPYB'),
#  Row(customerID='6035-BXTTY'),
#  Row(customerID='6885-PKOAM'),
#  Row(customerID='7520-HQWJU'),
#  Row(customerID='9639-BUJXT'),
#  Row(customerID='5924-SNGKP'),
#  Row(customerID='0021-IKXGC'),
#  Row(customerID='2034-GDRCN'),
#  Row(customerID='8966-SNIZF'),
#  Row(customerID='6243-OZGFH'),
#  Row(customerID='4654-DLAMQ'),
#  Row(customerID='0513-RBGPE'),
#  Row(customerID='5160-UXJED'),
#  Row(customerID='4115-NZRKS'),
#  Row(customerID='0219-YTZUE'),
#  Row(customerID='0623-IIHUG'),
#  Row(customerID='4572-DVCGN'),
#  Row(customerID='3351-NGXYI'),
#  Row(customerID='8984-EYLLL'),
#  Row(customerID='9057-MSWCO'),
#  Row(customerID='9833-TGFHX'),
#  Row(customerID='9294-TDIPC'),
#  Row(customerID='5229-DTFYB'),
#  Row(customerID='0104-PPXDV'),
#  Row(customerID='5176-LMJXE'),
#  Row(customerID='3583-KRKMD'),
#  Row(customerID='1010-DIAUQ'),
#  Row(customerID='9069-LGEUL'),
#  Row(customerID='7302-ZHMHP'),
#  Row(customerID='9571-EDEBV'),
#  Row(customerID='3520-FJGCV'),
#  Row(customerID='6563-VRERX'),
#  Row(customerID='0259-GBZSH'),
#  Row(customerID='6122-EFVKN'),
#  Row(customerID='2805-EDJPQ'),
#  Row(customerID='6862-CQUMB'),
#  Row(customerID='7156-MXBJE'),
#  Row(customerID='6158-HDPXZ'),
#  Row(customerID='9601-BRXPO'),
#  Row(customerID='2863-IMQDR'),
#  Row(customerID='5686-CMAWK'),
#  Row(customerID='5651-CRHKQ'),
#  Row(customerID='6905-NIQIN'),
#  Row(customerID='8204-YJCLA'),
#  Row(customerID='5167-ZFFMM'),
#  Row(customerID='6583-SZVGP'),
#  Row(customerID='4895-TMWIR'),
#  Row(customerID='0533-BNWKF'),
#  Row(customerID='1708-PBBOA'),
#  Row(customerID='8782-LKFPK'),
#  Row(customerID='5522-JBWMO'),
#  Row(customerID='3597-MVHJT'),
#  Row(customerID='9774-NRNAU'),
#  Row(customerID='0224-RLWWD'),
#  Row(customerID='9967-ATRFS'),
#  Row(customerID='3951-NJCVI'),
#  Row(customerID='2977-CEBSX'),
#  Row(customerID='0177-PXBAT'),
#  Row(customerID='6599-CEBNN'),
#  Row(customerID='2519-ERQOJ'),
#  Row(customerID='5876-QMYLD'),
#  Row(customerID='2277-AXSDC'),
#  Row(customerID='9442-JTWDL'),
#  Row(customerID='0979-PHULV'),
#  Row(customerID='3067-SVMTC'),
#  Row(customerID='5495-GPSRW'),
#  Row(customerID='7606-BPHHN'),
#  Row(customerID='4742-DRORA'),
#  Row(customerID='0111-KLBQG'),
#  Row(customerID='4800-VHZKI'),
#  Row(customerID='7989-CHGTL'),
#  Row(customerID='0334-GDDSO'),
#  Row(customerID='4163-NCJAK'),
#  Row(customerID='5233-AOZUF'),
#  Row(customerID='5973-EJGDP'),
#  Row(customerID='1996-DBMUS'),
#  Row(customerID='7916-VCCPB'),
#  Row(customerID='4686-GEFRM'),
#  Row(customerID='5249-QYHEX'),
#  Row(customerID='0578-SKVMF'),
#  Row(customerID='5564-NEMQO'),
#  Row(customerID='2233-FAGXV'),
#  Row(customerID='5605-IYGFG'),
#  Row(customerID='7663-ZTEGJ'),
#  Row(customerID='3935-TBRZZ'),
#  Row(customerID='8111-BKVDS'),
#  Row(customerID='2055-SIFSS'),
#  Row(customerID='2806-MLNTI'),
#  Row(customerID='8734-DKSTZ'),
#  Row(customerID='4360-PNRQB'),
#  Row(customerID='6152-ONASV'),
#  Row(customerID='9063-ZGTUY'),
#  Row(customerID='7781-HVGMK'),
#  Row(customerID='2181-UAESM'),
#  Row(customerID='2957-LOLHO'),
#  Row(customerID='6048-NJXHX'),
#  Row(customerID='2320-SLKMB'),
#  Row(customerID='4980-URKXC'),
#  Row(customerID='4376-KFVRS'),
#  Row(customerID='5886-VLQVU'),
#  Row(customerID='3577-AMVUX'),
#  Row(customerID='0771-WLCLA'),
#  Row(customerID='5628-RKIFK'),
#  Row(customerID='0206-TBWLC'),
#  Row(customerID='2937-FTHUR'),
#  Row(customerID='1910-FMXJM'),
#  Row(customerID='7752-XUSCI'),
#  Row(customerID='4110-PFEUZ'),
#  Row(customerID='0732-OCQOC'),
#  Row(customerID='5168-MSWXT'),
#  Row(customerID='1090-ESELR'),
#  Row(customerID='8592-PLTMQ'),
#  Row(customerID='5760-WRAHC'),
#  Row(customerID='8847-GEOOQ'),
#  Row(customerID='0256-LTHVJ'),
#  Row(customerID='4785-FCIFB'),
#  Row(customerID='8313-NDOIA'),
#  Row(customerID='5149-CUZUJ'),
#  Row(customerID='0942-KOWSM'),
#  Row(customerID='4237-CLSMM'),
#  Row(customerID='1452-VOQCH'),
#  Row(customerID='4719-UMSIY'),
#  Row(customerID='6614-VBEGU'),
#  Row(customerID='0880-TKATG'),
#  Row(customerID='3811-VBYBZ'),
#  Row(customerID='1480-BKXGA'),
#  Row(customerID='2996-XAUVF'),
#  Row(customerID='9076-AXYIK'),
#  Row(customerID='5968-XQIVE'),
#  Row(customerID='8896-RAZCR'),
#  Row(customerID='4640-UHDOS'),
#  Row(customerID='4933-IKULF'),
#  Row(customerID='3583-EKAPL'),
#  Row(customerID='1304-BCCFO'),
#  Row(customerID='4104-PVRPS'),
#  Row(customerID='9399-APLBT'),
#  Row(customerID='2359-KMGLI'),
#  Row(customerID='3780-DDGSE'),
#  Row(customerID='4431-EDMIQ'),
#  Row(customerID='0306-JAELE'),
#  Row(customerID='6227-HWPWX'),
#  Row(customerID='0486-LGCCH'),
#  Row(customerID='0447-BEMNG'),
#  Row(customerID='4612-SSVHJ'),
#  Row(customerID='5168-MQQCA'),
#  Row(customerID='5949-XIKAE'),
#  Row(customerID='7971-HLVXI'),
#  Row(customerID='9094-AZPHK'),
#  Row(customerID='3649-JPUGY'),
#  Row(customerID='4472-LVYGI'),
#  Row(customerID='8372-JUXUI'),
#  Row(customerID='3552-CTCYF'),
#  Row(customerID='6778-YSNIH'),
#  Row(customerID='0388-EOPEX'),
#  Row(customerID='5756-OZRIO'),
#  Row(customerID='6579-JPICP'),
#  Row(customerID='8205-OTCHB'),
#  Row(customerID='4134-BSXLX'),
#  Row(customerID='0505-SPOOW'),
#  Row(customerID='6235-VDHOM'),
#  Row(customerID='7783-YKGDV'),
#  Row(customerID='4374-YMUSQ'),
#  Row(customerID='4513-CXYIX'),
#  Row(customerID='3957-HHLMR'),
#  Row(customerID='7803-XOCCZ'),
#  Row(customerID='5736-YEJAX'),
#  Row(customerID='5609-CEBID'),
#  Row(customerID='8981-FJGLA'),
#  Row(customerID='7218-HKQFK'),
#  Row(customerID='4636-QRJKY'),
#  Row(customerID='1135-LMECX'),
#  Row(customerID='4332-MUOEZ'),
#  Row(customerID='8535-SFUTN'),
#  Row(customerID='5956-VKDTT'),
#  Row(customerID='8677-HDZEE'),
#  Row(customerID='2475-MROZF'),
#  Row(customerID='9412-GHEEC'),
#  Row(customerID='3482-ABPKK'),
#  Row(customerID='6705-LXORM'),
#  Row(customerID='0257-ZESQC'),
#  Row(customerID='7531-GQHME'),
#  Row(customerID='5174-ITUMV'),
#  Row(customerID='4109-CYRBD'),
#  Row(customerID='0913-XWSCN'),
#  Row(customerID='6825-UYPFK'),
#  Row(customerID='8397-MVTAZ'),
#  Row(customerID='0750-EBAIU'),
#  Row(customerID='8606-CIQUL'),
#  Row(customerID='3571-DPYUH'),
#  Row(customerID='7601-GNDYK'),
#  Row(customerID='0356-OBMAC'),
#  Row(customerID='8067-NIOYM'),
#  Row(customerID='1403-GYAFU'),
#  Row(customerID='4234-XTNEA'),
#  Row(customerID='1297-VQDRP'),
#  Row(customerID='9282-IZGQK'),
#  Row(customerID='5348-CAGXB'),
#  Row(customerID='0621-HJWXJ'),
#  Row(customerID='5844-QVTAT'),
#  Row(customerID='8905-IAZPF'),
#  Row(customerID='5394-MEITZ'),
#  Row(customerID='6859-QNXIQ'),
#  Row(customerID='2782-LFZVW'),
#  Row(customerID='2866-IKBTM'),
#  Row(customerID='1342-JPNKI'),
#  Row(customerID='2817-NTQDO'),
#  Row(customerID='7129-AZJDE'),
#  Row(customerID='6986-IJDHX'),
#  Row(customerID='2560-PPCHE'),
#  Row(customerID='4676-MQUEA'),
#  Row(customerID='8138-EALND'),
#  Row(customerID='3580-HYCSP'),
#  Row(customerID='1352-HNSAW'),
#  Row(customerID='2075-PUEPR'),
#  Row(customerID='1982-FEBTD'),
#  Row(customerID='5301-GAUUY'),
#  Row(customerID='5791-KAJFD'),
#  Row(customerID='2654-VBVPB'),
#  Row(customerID='1154-HYWWO'),
#  Row(customerID='2501-XWWTZ'),
#  Row(customerID='3716-UVSPD'),
#  Row(customerID='6815-ABQFQ'),
#  Row(customerID='7343-EOBEU'),
#  Row(customerID='3701-SFMUH'),
#  Row(customerID='6103-LIANB'),
#  Row(customerID='7319-VENRZ'),
#  Row(customerID='5846-NEQVZ'),
#  Row(customerID='6967-QIQRV'),
#  Row(customerID='5781-RFZRP'),
#  Row(customerID='0939-YAPAF'),
#  Row(customerID='0308-IVGOK'),
#  Row(customerID='7293-LSCDV'),
#  Row(customerID='7025-WCBNE'),
#  Row(customerID='5756-JYOJT'),
#  Row(customerID='4710-FDUIZ'),
#  Row(customerID='6030-REHUX'),
#  Row(customerID='9548-LIGTA'),
#  Row(customerID='5150-LJNSR'),
#  Row(customerID='8270-RKSAP'),
#  Row(customerID='6522-YRBXD'),
#  Row(customerID='2640-LYMOV'),
#  Row(customerID='1218-VKFPE'),
#  Row(customerID='3627-FHKBK'),
#  Row(customerID='2865-TCHJW'),
#  Row(customerID='1423-BMPBQ'),
#  Row(customerID='2393-DIVAI'),
#  Row(customerID='5192-EBGOV'),
#  Row(customerID='4568-KNYWR'),
#  Row(customerID='8752-IMQOS'),
#  Row(customerID='0742-LAFQK'),
#  Row(customerID='0795-LAFGP'),
#  Row(customerID='0619-OLYUR'),
#  Row(customerID='5512-IDZEI'),
#  Row(customerID='0459-SPZHJ'),
#  Row(customerID='0215-BQKGS'),
#  Row(customerID='9244-ZVAPM'),
#  Row(customerID='0719-SYFRB'),
#  Row(customerID='8208-EUMTE'),
#  Row(customerID='5172-MIGPM'),
#  Row(customerID='1710-RCXUS'),
#  Row(customerID='0374-FIUCA'),
#  Row(customerID='5839-SUYVZ'),
#  Row(customerID='5173-ZXXXL'),
#  Row(customerID='1096-ADRUX'),
#  Row(customerID='2001-MCUUW'),
#  Row(customerID='2731-GJRDG'),
#  Row(customerID='4723-BEGSG'),
#  Row(customerID='6516-NKQBO'),
#  Row(customerID='8672-OAUPW'),
#  Row(customerID='8207-DMRVL'),
#  Row(customerID='3419-SNJJD'),
#  Row(customerID='6543-CPZMK'),
#  Row(customerID='4765-OXPPD'),
#  Row(customerID='2804-ETQDK'),
#  Row(customerID='6689-VRRTK'),
#  Row(customerID='7138-GIRSH'),
#  Row(customerID='9396-ZSFLL'),
#  Row(customerID='6464-KEXXH'),
#  Row(customerID='7134-MJPDY'),
#  Row(customerID='5240-CAOYT'),
#  Row(customerID='4059-IIEBK'),
#  Row(customerID='4881-JVQOD'),
#  Row(customerID='0516-UXRMT'),
#  Row(customerID='4851-BQDNX'),
#  Row(customerID='5148-HKFIR'),
#  Row(customerID='1009-IRMNA'),
#  Row(customerID='3003-CMDUU'),
#  Row(customerID='5016-IBERQ'),
#  Row(customerID='6797-UCJHZ'),
#  Row(customerID='2469-DTSGX'),
#  Row(customerID='4554-YGZIH'),
#  Row(customerID='5099-BAILX'),
#  Row(customerID='9931-KGHOA'),
#  Row(customerID='1775-KWJKQ'),
#  Row(customerID='7665-VIGUD'),
#  Row(customerID='9411-TPQQV'),
#  Row(customerID='7207-RMRDB'),
#  Row(customerID='7954-MLBUN'),
#  Row(customerID='2077-DDHJK'),
#  Row(customerID='4913-EHYUI'),
#  Row(customerID='0195-IESCP'),
#  Row(customerID='9574-BOSMD'),
#  Row(customerID='4580-TMHJU'),
#  Row(customerID='0970-ETWGE'),
#  Row(customerID='4908-XAXAY'),
#  Row(customerID='8404-VLQFB'),
#  Row(customerID='1626-ERCMM'),
#  Row(customerID='0887-HJGAR'),
#  Row(customerID='2391-IPLOP'),
#  Row(customerID='5644-PDMZC'),
#  Row(customerID='3509-GWQGF'),
#  Row(customerID='9576-ANLXO'),
#  Row(customerID='2024-BASKD'),
#  Row(customerID='5845-BZZIB'),
#  Row(customerID='1140-UKVZG'),
#  Row(customerID='4160-AMJTL'),
#  Row(customerID='5183-SNMJQ'),
#  Row(customerID='8100-PNJMH'),
#  Row(customerID='7838-LAZFO'),
#  Row(customerID='4464-JCOLN'),
#  Row(customerID='2085-JVGAD'),
#  Row(customerID='5650-VDUDS'),
#  Row(customerID='8095-WANWK'),
#  Row(customerID='3030-ZKIWL'),
#  Row(customerID='9565-FLVCG'),
#  Row(customerID='8755-OGKNA'),
#  Row(customerID='2800-VEQXM'),
#  Row(customerID='7538-GWHML'),
#  Row(customerID='5533-RJFTJ'),
#  Row(customerID='3859-CVCET'),
#  Row(customerID='0214-JHPFW'),
#  Row(customerID='5642-MHDQT'),
#  Row(customerID='3088-FVYWK'),
#  Row(customerID='3276-HDUEG'),
#  Row(customerID='9092-GDZKO'),
#  Row(customerID='0823-HSCDJ'),
#  Row(customerID='3729-OWRVL'),
#  Row(customerID='2324-AALNO'),
#  Row(customerID='0822-GAVAP'),
#  Row(customerID='5760-IFJOZ'),
#  Row(customerID='2826-UWHIS'),
#  Row(customerID='1448-PWKYE'),
#  Row(customerID='7501-IWUNG'),
#  Row(customerID='4957-TREIR'),
#  Row(customerID='7251-LJBQN'),
#  Row(customerID='8040-MNRTF'),
#  Row(customerID='1536-HBSWP'),
#  Row(customerID='5313-FPXWG'),
#  Row(customerID='0067-DKWBL'),
#  Row(customerID='0946-FKYTX'),
#  Row(customerID='5076-YVXCM'),
#  Row(customerID='8262-COGGB'),
#  Row(customerID='6663-JOCQO'),
#  Row(customerID='9620-QJREV'),
#  Row(customerID='2276-YDAVZ'),
#  Row(customerID='2682-KEVRP'),
#  Row(customerID='2480-JZOSN'),
#  Row(customerID='0078-XZMHT'),
#  Row(customerID='5896-NPFWW'),
#  Row(customerID='9978-HYCIN'),
#  Row(customerID='8338-QIUNR'),
#  Row(customerID='1525-LNLOJ'),
#  Row(customerID='9450-TRJUU'),
#  Row(customerID='1766-GKNMI'),
#  Row(customerID='6942-LBFDP'),
#  Row(customerID='1456-TWCGB'),
#  Row(customerID='7133-VBDCG'),
#  Row(customerID='7596-ZYWBB'),
#  Row(customerID='8329-UTMVM'),
#  Row(customerID='3014-WJKSM'),
#  Row(customerID='3347-YJZZE'),
#  Row(customerID='1029-QFBEN'),
#  Row(customerID='7929-DMBCV'),
#  Row(customerID='9661-JALZV'),
#  Row(customerID='5433-KYGHE'),
#  Row(customerID='4312-KFRXN'),
#  Row(customerID='5575-TPIZQ'),
#  Row(customerID='0114-IGABW'),
#  Row(customerID='9944-AEXBM'),
#  Row(customerID='1853-ARAAQ'),
#  Row(customerID='6952-OMNWB'),
#  Row(customerID='4697-LUPSU'),
#  Row(customerID='8434-VGEQQ'),
#  Row(customerID='4952-YSOGZ'),
#  Row(customerID='1589-AGTLK'),
#  Row(customerID='5244-IRFIH'),
#  Row(customerID='6549-YMFAW'),
#  Row(customerID='4950-HKQTE'),
#  Row(customerID='6786-OBWQR'),
#  Row(customerID='2684-EIWEO'),
#  Row(customerID='2753-JMMCV'),
#  Row(customerID='6439-GTPCA'),
#  Row(customerID='6621-YOBKI'),
#  Row(customerID='1216-JWVUX'),
#  Row(customerID='7564-GHCVB'),
#  Row(customerID='1173-NOEYG'),
#  Row(customerID='7595-EHCDL'),
#  Row(customerID='6647-ZEDXT'),
#  Row(customerID='2521-NPUZR'),
#  Row(customerID='1307-TVUFB'),
#  Row(customerID='7503-MIOGA'),
#  Row(customerID='4381-MHQDC'),
#  Row(customerID='6923-JHPMP'),
#  Row(customerID='5138-WVKYJ'),
#  Row(customerID='4018-PPNDW'),
#  Row(customerID='1635-FJFCC'),
#  Row(customerID='2499-AJYUA'),
#  Row(customerID='6919-ELBGL'),
#  Row(customerID='3966-HRMZA'),
#  Row(customerID='6425-JWTDV'),
#  Row(customerID='8405-IGQFX'),
#  Row(customerID='8224-IVVPA'),
#  Row(customerID='9477-LGWQI'),
#  Row(customerID='1410-RSCMR'),
#  Row(customerID='3115-CZMZD'),
#  Row(customerID='0139-IVFJG'),
#  Row(customerID='6683-VLCTZ'),
#  Row(customerID='5730-DBDSI'),
#  Row(customerID='0030-FNXPP'),
#  Row(customerID='2189-WWOEW'),
#  Row(customerID='5684-FJVYR'),
#  Row(customerID='4013-GUXND'),
#  Row(customerID='1894-IGFSG'),
#  Row(customerID='7379-POKDZ'),
#  Row(customerID='1266-NZYUI'),
#  Row(customerID='7969-FFOWG'),
#  Row(customerID='4718-DHSMV'),
#  Row(customerID='5175-WLYXL'),
#  Row(customerID='7817-OMJNA'),
#  Row(customerID='8728-SKJLR'),
#  Row(customerID='3137-NYQQI'),
#  Row(customerID='7706-DZNKK'),
#  Row(customerID='0236-HFWSV'),
#  Row(customerID='3900-AQPHZ'),
#  Row(customerID='5842-POCOP'),
#  Row(customerID='2037-XJFUP'),
#  Row(customerID='8823-RLPWL'),
#  Row(customerID='9505-SQFSW'),
#  Row(customerID='7314-OXENN'),
#  Row(customerID='3758-CKOQL'),
#  Row(customerID='0322-CHQRU'),
#  Row(customerID='5676-CFLYY'),
#  Row(customerID='7521-AFHAB'),
#  Row(customerID='0285-INHLN'),
#  Row(customerID='4678-DVQEO'),
#  Row(customerID='5125-CNDSP'),
#  Row(customerID='0691-IFBQW'),
#  Row(customerID='4992-LTJNE'),
#  Row(customerID='2202-OUTMO'),
#  Row(customerID='0810-BDHAW'),
#  Row(customerID='0229-LFJAF'),
#  Row(customerID='7131-ZQZNK'),
#  Row(customerID='3442-ZHHCC'),
#  Row(customerID='5726-CVNYA'),
#  Row(customerID='9871-ELEYA'),
#  Row(customerID='4257-GAESD'),
#  Row(customerID='5173-WXOQV'),
#  Row(customerID='2040-OBMLJ'),
#  Row(customerID='6286-ZHAOK'),
#  Row(customerID='3807-XHCJH'),
#  Row(customerID='3009-JWMPU'),
#  Row(customerID='5671-RQRLP'),
#  Row(customerID='1450-GALXR'),
#  Row(customerID='8859-AXJZP'),
#  Row(customerID='3174-AKMAS'),
#  Row(customerID='3138-BKYAV'),
#  Row(customerID='9926-PJHDQ'),
#  Row(customerID='7382-DFJTU'),
#  Row(customerID='2798-NYLMZ'),
#  Row(customerID='4289-DTDKW'),
#  Row(customerID='1820-TQVEV'),
#  Row(customerID='2239-JALAW'),
#  Row(customerID='4853-RULSV'),
#  Row(customerID='8098-TDCBU'),
#  Row(customerID='3551-GAEGL'),
#  Row(customerID='4785-NKHCX'),
#  Row(customerID='3196-NVXLZ'),
#  Row(customerID='6275-YDUVO'),
#  Row(customerID='0036-IHMOT'),
#  Row(customerID='0115-TFERT'),
#  Row(customerID='4178-EGMON'),
#  Row(customerID='4220-TINQT'),
#  Row(customerID='5318-YKDPV'),
#  Row(customerID='7975-TZMLR'),
#  Row(customerID='0295-QVKPB'),
#  Row(customerID='4335-BSMJS'),
#  Row(customerID='2311-QYMUQ'),
#  Row(customerID='3643-AHCFP'),
#  Row(customerID='9146-JRIOX'),
#  Row(customerID='3104-OWCGK'),
#  Row(customerID='5337-IIWKZ'),
#  Row(customerID='9101-BWFSS'),
#  Row(customerID='9650-VBUOG'),
#  Row(customerID='3487-EARAT'),
#  Row(customerID='2672-TGEFF'),
#  Row(customerID='9231-ZJYAM'),
#  Row(customerID='4250-WAROZ'),
#  Row(customerID='8184-WMOFI'),
#  Row(customerID='6982-SSHFK'),
#  Row(customerID='6092-QZVPP'),
#  Row(customerID='4625-LAMOB'),
#  Row(customerID='0727-BMPLR'),
#  Row(customerID='0392-BZIUW'),
#  Row(customerID='1038-ZAGBI'),
#  Row(customerID='6549-NNDYT'),
#  Row(customerID='3027-ZTDHO'),
#  Row(customerID='0422-OHQHQ'),
#  Row(customerID='6916-HIJSE'),
#  Row(customerID='2316-ESMLS'),
#  Row(customerID='9778-OGKQZ'),
#  Row(customerID='7408-OFWXJ'),
#  Row(customerID='6007-TCTST'),
#  Row(customerID='2252-NKNSI'),
#  Row(customerID='8713-IGZSO'),
#  Row(customerID='7905-TVXTA'),
#  Row(customerID='7695-PKLCZ'),
#  Row(customerID='2382-BCKQJ'),
#  Row(customerID='8374-UULRV'),
#  Row(customerID='2207-NHRJK'),
#  Row(customerID='3224-DFQNQ'),
#  Row(customerID='5275-PMFUT'),
#  Row(customerID='4795-UXVCJ'),
#  Row(customerID='9777-IQHWP'),
#  Row(customerID='0947-MUGVO'),
#  Row(customerID='9944-HKVVB'),
#  Row(customerID='4124-MMETB'),
#  Row(customerID='3671-SHRSP'),
#  Row(customerID='0979-MOZQI'),
#  Row(customerID='2732-ISEZX'),
#  Row(customerID='3313-QKNKB'),
#  Row(customerID='0323-XWWTN'),
#  Row(customerID='1937-OTUKY'),
#  Row(customerID='1573-LGXBA'),
#  Row(customerID='1764-VUUMT'),
#  Row(customerID='5073-WXOYN'),
#  Row(customerID='4713-ZBURT'),
#  Row(customerID='3050-GBUSH'),
#  Row(customerID='0207-MDKNV'),
#  Row(customerID='7876-AEHIG'),
#  Row(customerID='7945-HLKEA'),
#  Row(customerID='9342-VNIMQ'),
#  Row(customerID='9851-KIELU'),
#  Row(customerID='3523-BRGUW'),
#  Row(customerID='3908-BLSYF'),
#  Row(customerID='3199-NPKCN'),
#  Row(customerID='5170-PTRKA'),
#  Row(customerID='4661-NJEUX'),
#  Row(customerID='2123-AGEEN'),
#  Row(customerID='1258-YMZNM'),
#  Row(customerID='0048-LUMLS'),
#  Row(customerID='7549-MYGPK'),
#  Row(customerID='5898-IGSLP'),
#  Row(customerID='3804-RVTGV'),
#  Row(customerID='6259-WJQLC'),
#  Row(customerID='9227-LUNBG'),
#  Row(customerID='7997-EASSD'),
#  Row(customerID='0730-KOAVE'),
#  Row(customerID='8975-SKGRX'),
#  Row(customerID='0678-RLHVP'),
#  Row(customerID='4315-MURBD'),
#  Row(customerID='2267-FPIMA'),
#  Row(customerID='1051-GEJLJ'),
#  Row(customerID='9734-YWGEX'),
#  Row(customerID='2719-BDAQO'),
#  Row(customerID='5285-MVEHD'),
#  Row(customerID='0379-DJQHR'),
#  Row(customerID='0781-LKXBR'),
#  Row(customerID='5543-QDCRY'),
#  Row(customerID='0297-RBCSG'),
#  Row(customerID='4694-PHWFW'),
#  Row(customerID='0835-JKADZ'),
#  Row(customerID='1907-UBQFC'),
#  Row(customerID='7508-SMHXL'),
#  Row(customerID='3865-YIOTT'),
#  Row(customerID='5993-BQHEA'),
#  Row(customerID='6024-RUGGH'),
#  Row(customerID='6513-EECDB'),
#  Row(customerID='3956-CJUST'),
#  Row(customerID='4079-WWQQQ'),
#  Row(customerID='6103-BOCOU'),
#  Row(customerID='5149-TGWDZ'),
#  Row(customerID='7471-WNSUF'),
#  Row(customerID='8942-DBMHZ'),
#  Row(customerID='4301-VVZKA'),
#  Row(customerID='9199-PWQVC'),
#  Row(customerID='4824-GUCBY'),
#  Row(customerID='5393-HJZSM'),
#  Row(customerID='7074-IEVOJ'),
#  Row(customerID='9625-QSTYE'),
#  Row(customerID='0862-PRCBS'),
#  Row(customerID='8812-ZRHFP'),
#  Row(customerID='5146-CBVOE'),
#  Row(customerID='0454-OKRCT'),
#  Row(customerID='5787-KXGIY'),
#  Row(customerID='4750-ZRXIU'),
#  Row(customerID='4198-VFOEA'),
#  Row(customerID='6630-UJZMY'),
#  Row(customerID='5709-LVOEQ'),
#  Row(customerID='6400-BWQKW'),
#  Row(customerID='2692-AQCPF'),
#  Row(customerID='0347-UBKUZ'),
#  Row(customerID='0835-DUUIQ'),
#  Row(customerID='0811-GSDTP'),
#  Row(customerID='7567-ECMCM'),
#  Row(customerID='6115-ZTBFQ'),
#  Row(customerID='6353-BRMMA'),
#  Row(customerID='6680-WKXRZ'),
#  Row(customerID='6231-WFGFH'),
#  Row(customerID='9904-EHEVJ'),
#  Row(customerID='7028-DVOIQ'),
#  Row(customerID='6169-PPETC'),
#  Row(customerID='4208-UFFGW'),
#  Row(customerID='8584-KMVXD'),
#  Row(customerID='8467-WYNSR'),
#  Row(customerID='0851-DFJKB'),
#  Row(customerID='5382-SOYZL'),
#  Row(customerID='9448-REEVD'),
#  Row(customerID='3261-CQXOL'),
#  Row(customerID='8388-FYNPZ'),
#  Row(customerID='4002-BQWPQ'),
#  Row(customerID='5651-YLPRD'),
#  Row(customerID='2826-DXLQO'),
#  Row(customerID='4378-BZYFP'),
#  Row(customerID='9489-UTFKA'),
#  Row(customerID='4849-PYRLQ'),
#  Row(customerID='9117-SHLZX'),
#  Row(customerID='9889-TMAHG'),
#  Row(customerID='4541-RMRLG'),
#  Row(customerID='7764-BDPEE'),
#  Row(customerID='3429-IFLEM'),
#  Row(customerID='3158-MOERK'),
#  Row(customerID='7294-TMAOP'),
#  Row(customerID='5002-GCQFH'),
#  Row(customerID='0556-FJEGU'),
#  Row(customerID='8919-FYFQZ'),
#  Row(customerID='0604-THJFP'),
#  Row(customerID='2834-JRTUA'),
#  Row(customerID='5875-YPQFJ'),
#  Row(customerID='5879-SESNB'),
#  Row(customerID='6646-QVXLR'),
#  Row(customerID='6461-PPAXN'),
#  Row(customerID='3318-ISQFQ'),
#  Row(customerID='1106-HRLKZ'),
#  Row(customerID='2483-XSSMZ'),
#  Row(customerID='8603-IJWDN'),
#  Row(customerID='8165-ZJRNM'),
#  Row(customerID='9369-XFEHK'),
#  Row(customerID='2604-XVDAM'),
#  Row(customerID='3717-OFRTN'),
#  Row(customerID='9046-JBFWA'),
#  Row(customerID='3280-NMUVX'),
#  Row(customerID='1206-EHBDD'),
#  Row(customerID='8361-LBRDI'),
#  Row(customerID='4883-KCPZJ'),
#  Row(customerID='9108-EQPNQ'),
#  Row(customerID='7277-KAMWT'),
#  Row(customerID='3842-IYKUE'),
#  Row(customerID='6641-XRPSU'),
#  Row(customerID='1374-DMZUI'),
#  Row(customerID='2545-LXYVJ'),
#  Row(customerID='3234-VKACU'),
#  ...]

# %% [markdown]
# ## Collect List & Collect Set

# %% [markdown]
# Use collect_list to return all values from a column **with** duplicates

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

from pyspark.sql import functions as F

df.select(F.collect_list("TotalCharges")).show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |collect_list(TotalCharges)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[29.85, 1889.5, 108.15, 1840.75, 151.65, 820.5, 1949.4, 301.9, 3046.05, 3487.95, 587.45, 326.8, 5681.1, 5036.3, 2686.05, 7895.15, 1022.95, 7382.25, 528.35, 1862.9, 39.65, 202.25, 20.15, 3505.1, 2970.3, 1530.6, 4749.15, 30.2, 6369.45, 1093.1, 6766.95, 181.65, 1874.45, 20.2, 45.25, 7251.7, 316.9, 3548.3, 3549.25, 1105.4, 475.7, 4872.35, 418.25, 4861.45, 981.45, 3906.7, 97, 144.15, 4217.8, 4254.1, 3838.75, 1426.4, 1752.65, 633.3, 4456.35, 1752.55, 6311.2, 7076.35, 894.3, 7853.7, 4707.1, 5450.7, 2962, 957.1, 857.25, 244.1, 3650.35, 2497.2, 930.9, 887.35, 49.05, 1090.65, 7099, 1424.6, 177.4, 6139.5, 2688.85, 482.25, 2111.3, 1216.6, 79.35, 565.35, 496.9, 4327.5, 973.35, 918.75, 2215.45, 1057, 927.1, 1009.25, 2570.2, 74.7, 5714.25, 7107, 7459.05, 927.35, 4748.7, 113.85, 1107.2, 2514.5, 20.2, 19.45, 3605.6, 3027.25, 7611.85, 100.2, 7303.05, 927.65, 3921.3, 1363.25, 5238.9, 3042.25, 3954.1, 2868.15, 3423.5, 248.4, 1126.35, 1064.65, 835.15, 2151.6, 5515.45, 112.75, 229.55, 350.35, 62.9, 3027.65, 2135.5, 1723.95, 19.75, 3985.35, 1215.65, 1502.65, 3260.1, 35.45, 81.25, 1188.2, 1778.5, 1277.75, 1170.55, 70.45, 6425.65, 563.65, 5971.25, 5289.05, 1756.2, 6416.7, 61.35, 45.65, 1929.95, 1071.4, 564.35, 655.5, 7930.55, 5215.25, 113.5, 1152.8, 1821.95, 419.9, 1024, 251.6, 764.55, 1592.35, 135.2, 3958.25, 233.9, 1363.45, 273, 6254.45, 2651.2, 321.4, 3539.25, 242.8, 1181.75, 5000.2, 654.55, 780.2, 1145.7, 503.6, 1559.25, 1252, 29.95, 45.3, 662.65, 2453.3, 1111.65, 24.8, 1023.85, 82.15, 244.8, 2379.1, 3173.35, 531, 1375.4, 8129.3, 1192.7, 1901.65, 587.4, 6519.75, 8041.65, 20.75, 2681.15, 1112.3, 7405.5, 1033.95, 2958.95, 2684.85, 4179.2, 79.9, 1934.45, 6654.1, 84.5, 25.25, 1124.2, 540.05, 1975.85, 3437.45, 3139.8, 3789.2, 5324.5, 624.6, 268.35, 1836.9, 20.2, 179.35, 219.35, 1288.75, 2545.75, 55.2, 2723.15, 4107.25, 5760.65, 4747.5, 84.6, 1566.9, 702, 114.1, 299.05, 1305.95, 1120.3, 284.35, 6350.5, 7878.3, 3187.65, 6126.15, 731.3, 273.4, 2531.8, 1074.3, 48.55, 4298.45, 4619.55, 147.15, 40.2, 2633.3, 193.05, 4103.9, 7008.15, 5791.1, 80.55, 1228.65, 132.2, 1364.3, 4925.35, 1520.1, 5032.25, 5526.75, 1195.25, 2007.25, 1099.6, 1732.95, 1511.2, 3450.15, 24.8, 2172.05, 70.6, 401.1, 5624.85, 1339.8, 771.95, 244.75, 322.9, 498.25, 25.4, 3687.75, 1779.95, 1783.6, 927.15, 70, 606.55, 435.4, 1712.7, 2021.2, 1940.8, 567.8, 220.35, 20.25, 5436.45, 3437.5, 3015.75, 73.6, 1509.8, 396.1, 356.65, 4109, 3141.7, 1229.1, 2303.35, 2054.4, 3741.85, 3682.45, 19.25, 1886.25, 4895.1, 341.6, 415.55, 5686.4, 1355.1, 3058.65, 2231.05, 3236.35, 4350.1, 4264, 44.8, 422.3, 4176.7, 5138.1, 880.05, 139.05, 973.65, 1470.05, 739.35, 161.95, 4422.95, 511.25, 155.8, 5293.95, 4759.85, 6148.45, 3565.65, 6603, 1830.1, 6223.8, 4508.65, 1328.15, 865, 72.1, 168.2, 1303.5, 996.85, 6430.9, 2278.75, 681.4, 574.35, 371.9, 840.1, 846, 889, 6823.4, 805.1, 4016.75, 83.75, 3959.15, 2878.55, 945.7, 1373.05, 492.55, 1406, 19.15, 6962.85, 8126.65, 690.25, 181.5, 830.8, 5608.4, 3646.8, 3662.25, 25.35, 2566.5, 5308.7, 1410.25, 3339.05, 50.65, 4732.35, 90.85, 5067.45, 214.75, 4874.7, 2348.45, 4063, 44, 2595.25, 2309.55, 89.3, 367.55, 3944.5, 5965.95, 3694.7, 2524.45, 1803.7, 415.1, 624.15, 237.7, 7007.6, 3848.8, 419.4, 1468.75, 5812, 2861.45, 19.9, 19.6, 233.7, 1066.15, 2149.05, 4473, 3545.05, 1195.75, 6858.9, 1024.7, 1845.9, 75.3, 132.25, 515.45, 2830.45, 1110.5, 449.3, 2838.55, 5376.4, 858.6, 1395.05, 3975.7, 1182.55, 4784.45, 119.5, 518.9, 899.45, 1183.8, 720.05, 8468.2, 3161.2, 55.05, 1882.55, 5070.4, 6049.5, 1166.7, 2937.65, 6396.45, 69.55, 1270.25, 759.55, 7611.55, 1642.75, 1545.4, 3582.4, 2227.1, 1417.9, 2494.65, 2768.35, 2369.3, 38, 75.1, 100.9, 1614.05, 385.9, 673.25, 8404.9, 2799.75, 6538.45, 6588.95, 868.1, 734.35, 330.6, 55, 564.4, 1315.35, 74.7, 1861.5, 2747.2, 554.05, 453.4, 994.8, 225.75, 2145, 1671.6, 8003.8, 680.05, 6130.85, 1415, 6201.95,  , 74.35, 6597.25, 114.15, 139.4, 3902.6, 20.4, 903.6, 1785.65, 1397.65, 131.05, 1238.45, 3899.05, 5676, 4543.15, 4326.8, 5502.55, 1782.4, 851.8, 167.5 ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %% [markdown]
# Use collect_set to return all values from a column **without** duplicates

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

from pyspark.sql import functions as F

df.select(F.collect_set("TotalCharges")).show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |collect_set(TotalCharges)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[217.1, 2497.2, 4217.8, 233.65, 345.5, 4299.2, 7746.7, 70.8, 5424.25, 6342.7, 2954.5, 416.45, 8100.25, 5514.95, 5669.5, 966.25, 4685.55, 5435, 8022.85, 1521.2, 4735.2, 1088.25, 2168.9, 670.65, 1245.6, 6912.7, 1564.4, 3994.05, 7895.15, 2692.75, 830.7, 2838.7, 160.85, 3015.75, 1367.75, 1094.35, 1857.85, 5567.45, 1859.1, 1679.4, 58.9, 515.75, 1787.35, 3801.3, 851.2, 2390.45, 609.05, 2244.95, 6435.25, 582.5, 3263.6, 3474.05, 2210.2, 2479.25, 109.6, 1378.75, 3306.85, 2948.6, 948.9, 7171.7, 445.95, 79.5, 2684.85, 867.1, 321.9, 604.7, 156.1, 651.55, 497.3, 4273.45, 85, 5610.15, 7133.1, 273.25, 2576.2, 309.4, 158.35, 7138.65, 383.55, 1171.3, 59.05, 75.3, 813.3, 1830.05, 225.6, 4535.85, 3845.45, 1090.1, 3021.6, 4361.55, 346.45, 1181.75, 4453.3, 4888.7, 20.35, 89.5, 2020.9, 1643.25, 743.3, 5743.3, 5931.75, 2619.25, 1629.2, 5464.65, 1742.45, 1152.8, 5481.25, 237.2, 734.35, 3517.9, 3435.6, 1146.05, 35.75, 784.25, 1742.75, 1096.6, 150, 91.7, 4408.45, 2847.2, 2265, 2119.5, 893.55, 4652.4, 1836.9, 2989.6, 444.75, 3861.45, 167.5, 4555.2, 5730.7, 3375.9, 5844.65, 702.05, 899.45, 2603.3, 355.2, 4902.8, 4108.15, 2708.2, 223.15, 217.45, 4176.7, 896.75, 6614.9, 372.45, 18.85, 159.45, 428.45, 111.65, 299.05, 2782.4, 326.65, 3545.1, 2635, 522.35, 669.45, 2835.5, 348.15, 1130, 1743.9, 225.55, 2897.95, 1358.6, 679, 1527.5, 107.6, 1939.35, 5118.95, 89.3, 765.5, 80.95, 5921.35, 5186, 717.95, 116.95, 471.35, 4016.75, 7382.25, 1200.15, 3487.95, 442.85, 749.25, 2076.2, 1654.75, 381.3, 4116.8, 4543.95, 693.3, 106.85, 1253.5, 4793.8, 7413.55, 168.5, 1148.1, 1982.1, 2088.75, 315.3, 2333.05, 541.5, 3876.2, 2743.45, 916.15, 2111.45, 74.6, 1165.9, 2971.7, 4025.5, 19.95, 3342, 1539.8, 2033.05, 78.3, 439.75, 7039.05, 90.85, 2109.35, 6129.65, 6330.4, 913.3, 568.85, 334.8, 293.65, 419.9, 2890.65, 152.95, 3465.05, 955.75, 2386.85, 2283.3, 221.9, 25.1, 7222.75, 1175.6, 788.6, 563.5, 3371.75, 8308.9, 6141.65, 251.75, 4653.85, 309.1, 1400.85, 3444.85, 678.45, 2839.65, 5957.9, 809.25, 5116.6, 1046.2, 5728.55, 71.15, 57.4, 6880.85, 1326.35, 613.4, 747.2, 389.6, 155.65, 5341.8, 3474.2, 7922.75, 2681.15, 257, 772.4, 432.25, 4230.25, 21.05, 4890.5, 1789.25, 999.9, 4820.15, 939.7, 5560, 8196.4, 4919.7, 6376.55, 3190.65, 4753.85, 28.3, 554.25, 129.55, 6078.75, 655.9, 4903.2, 6185.8, 39.85, 2303.35, 451.55, 4677.1, 1118.8, 3415.25, 3662.25, 6886.25, 4264.25, 1126.75, 606.25, 296.1, 73.1, 417.5, 35, 23.45, 4720, 3942.45, 3921.1, 4738.85, 6997.3, 3340.55, 289.3, 68.35, 578.5, 1559.15, 435.25, 155.35, 8405, 4122.65, 483.7, 1505.35, 817.95, 1120.95, 504.2, 1493.75, 1769.6, 293.15, 1033.9, 2613.4, 19.4, 576.65, 411.45, 3851.45, 1374.9, 1411.9, 5034.05, 776.25, 4018.05, 3765.05, 790.15, 672.55, 3122.4, 1308.1, 4546, 422.5, 3990.6, 5125.75, 417.7, 3124.5, 1363.25, 4113.7, 1055.9, 503.6, 96.1, 2727.8, 6603, 52.05, 2656.5, 19.25, 780.2, 5265.55, 2633.95, 547.65, 1529.45, 3503.5, 1713.1, 76.45, 3769.7, 4718.25, 7511.65, 654.55, 493.95, 6703.5, 6431.05, 5661.7, 350.35, 6440.25, 5411.65, 6914.95, 171, 453.75, 475.25, 632.2, 6045.9, 1777.9, 2627.35, 73.05, 791.15, 229.5, 2320.8, 201.7, 75.5, 329.95, 2347.9, 834.2, 600.15, 494.9, 6302.8, 799.65, 113.55, 19.15, 763.1, 742.9, 2245.4, 1131.2, 743.05, 842.9, 1580.1, 1809.35, 3990.75, 764.95, 2106.3, 2283.15, 478.75, 2983.65, 5426.85, 2258.25, 4641.1, 4729.3, 2933.2, 45.2, 6767.1, 546.85, 6725.5, 4667, 38.15, 1071.4, 1077.95, 7030.65, 327.45, 6300.85, 1729.35, 1360.25, 781.4, 741.4, 7840.6, 438, 6225.4, 128.6, 93.3, 1500.95, 1887, 1573.95, 4600.7, 2424.5, 878.35, 3355.65, 1400.3, 530.05, 6555.2, 4517.25, 514.6, 791.7, 597.9, 903.6, 4888.2, 902, 4487.3, 447.75, 139.4, 7556.9, 362.6, 139.75, 571.75, 2249.1, 927.35, 7555, 3753.2, 967.85, 365.35, 1460.85, 19.05, 2995.45, 5253.95, 3741.85, 3250.45, 4908.25, 5986.55, 7517.7, 1734.2, 7578.05, 4855.35, 755.4, 5193.2, 8375.05, 79.6, 593.85, 1377.7, 7737.55, 7674.55, 196.15, 3264.5, 7386.05, 351.55, 724.65, 998.1, 7508.55, 5647.95, 100.35, 1662.05, 19.65, 174.7, 350.1, 2406.1, 3880.05, 3281.65, 4287.2, 59 ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %% [markdown]
# ## First & Last

# %% [markdown]
# Use first function to show the first row of a column

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

from pyspark.sql import functions as F

df.select(F.first("MonthlyCharges")).show(truncate=False)
# Out:
# +---------------------+
# |first(MonthlyCharges)|
# +---------------------+
# |29.85                |
# +---------------------+

# %% [markdown]
# Use last function to show the last row of a column

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)

from pyspark.sql import functions as F

df.select(F.last("MonthlyCharges")).show(truncate=False)
# Out:
# +--------------------+
# |last(MonthlyCharges)|
# +--------------------+
# |105.65              |
# +--------------------+
